# %% [markdown]
# ## Installation
#
# Install the required packages: `anthropic` for the API client and `python-dotenv` for environment variable management.

# %% [markdown]
# # Anthropic API - Chat Examples
#
# This notebook demonstrates how to use the Anthropic API to create conversational AI applications with Claude.

# %%
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Environment Setup
#
# Load environment variables from a `.env` file. Make sure you have your `ANTHROPIC_API_KEY` defined in the `.env` file.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialize Client
#
# Create an Anthropic client instance and specify the model to use.

# %%
from anthropic import Anthropic
client = Anthropic()   
model = "claude-sonnet-4-6"

# %% [markdown]
# ## Helper Functions
#
# Define utility functions to manage conversation messages and interact with the Claude API.

# %%
def add_user_message(messages ,text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)    

def chat(messages): 
    message = client.messages.create(
        model=model,
        messages=messages,
        max_tokens=100,
    )
    return message.content[0].text

# %% [markdown]
# ## Example 1: Multi-Turn Conversation
#
# This example shows how to maintain context across multiple exchanges with Claude.

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)
final_answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s and 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to explore vast numbers of possible solutions to a problem at the same time.'

# %% [markdown]
# ## Example 2: Interactive Chat Loop
#
# An interactive chat interface where you can have an ongoing conversation with Claude. Type 'exit' or 'quit' to end the conversation.

# %%
# Chat example with a loop

messages = []

while True:
    user_input = input("> ")
    print(">", user_input)
    if user_input.lower() in ['exit', 'quit']:
        print("Bye ! 👋")
        break
    
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("\n\n==================================\n\n")
    print(">", answer)
# Out:
# > hi
#
#
# ...
#
#
# > Hi there! How are you doing? Is there something I can help you with today? 😊
# > exit
# Bye ! 👋
